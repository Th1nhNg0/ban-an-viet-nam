# %%
import pandas as pd

# %%
df = pd.read_json("./output/banan.jsonl", lines=True)
df.head()
# Out:
#             id                                            url  \
# 0   2ta88t1cvn   https://congbobanan.toaan.gov.vn/2ta88t1cvn/
# 1   2ta89t1cvn   https://congbobanan.toaan.gov.vn/2ta89t1cvn/
# 2   2ta96t1cvn   https://congbobanan.toaan.gov.vn/2ta96t1cvn/
# 3   2ta98t1cvn   https://congbobanan.toaan.gov.vn/2ta98t1cvn/
# 4  2ta137t1cvn  https://congbobanan.toaan.gov.vn/2ta137t1cvn/
#
#                                          Tên bản án:  \
# 0  Ông NQT tranh chấp đất đai về đòi đất bị lấn ...
# 1  Kiện quyết định hành chính, hành vi hành chính...
# 2  T/c về trợ cấp thôi việc, bảo hiểm xã hội và b...
# 3  Bà Lê Thị Kim T khởi kiện bà Trần Thị Ái H về ...
# 4                                                NaN
#
#                                   Quan hệ pháp luật: Cấp xét xử:  \
# 0  Tranh chấp đất đai về đòi đất cho mượn, cho sử...   Phúc thẩm
# 1                                                NaN   Phúc thẩm
# 2  Tranh chấp về bồi thường thiệt hại, trợ cấp kh...   Phúc thẩm
# 3                    Tranh chấp hợp đồng vay tài sản     Sơ thẩm
# 4                                                NaN     Sơ thẩm
#
#   Loại vụ/việc:                         Tòa án xét xử: Áp dụng án lệ:  \
# 0        Dân sự                   TAND tỉnh Ninh Thuận          Không
# 1           NaN               TAND cấp cao tại Đà Nẵng          Không
# 2      Lao động                        TAND TP Đà Nẵng          Không
# 3        Dân sự  TAND huyện Đức Linh,  tỉnh Bình Thuận          Không
# 4           NaN        TAND huyện Sa Pa,  tỉnh Lào Cai          Không
#
#    Đính chính:                              Thông tin về vụ/việc:  \
# 0            0  Ông NQT khởi kiện Ông NVQ  đòi 02m chiều ng...
# 1            0                                                NaN
# 2            0                     nguyên đơn VCN bị đơn CTTNHHLT
# 3            0  Bà Lê Thị Kim T khởi kiện bà Trần Thị Ái H về ...
# 4            0                                                NaN
#
#                                 Đối tượng khởi kiện:    Loại án:  \
# 0                                                NaN         NaN
# 1  QĐ hành chính, hành vi hành chính về quản lý đ...  Hành chính
# 2                                                NaN         NaN
# 3                                                NaN         NaN
# 4                                                NaN         NaN
#
#                                  Thông tin về vụ án:  \
# 0                                                NaN
# 1  Bà Nguyễn Thị L kiện UBND huyện N, tỉnh Quảng Nam
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                  Tên quyết định:  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4  Quyết định áp dụng biện pháp xử lý hành chính
#
#          Biện pháp xử lý hành chính:  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4  Đưa vào cơ sở cai nghiện bắt buộc
#
#                                       Loại việc:  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4  Quyết định áp dụng biện pháp xử lý hành chính
#
#                                   Thông tin về việc: Đối tượng bị yêu cầu:  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                NaN                   NaN
# 3                                                NaN                   NaN
# 4  Đưa vào cơ sở cai nghiện bắt buộc đối với Hà A...                   NaN
#
#   Loại yêu cầu: Thông tin về yêu cầu:
# 0           NaN                   NaN
# 1           NaN                   NaN
# 2           NaN                   NaN
# 3           NaN                   NaN
# 4           NaN                   NaN

# %%
df.rename(
    columns={
        "Tên bản án:": "Ten_ban_an",
        "Quan hệ pháp luật:": "Quan_he_phap_luat",
        "Cấp xét xử:": "Cap_xet_xu",
        "Loại vụ/việc:": "Loai_vu_viec",
        "Tòa án xét xử:": "Toa_an_xet_xu",
        "Áp dụng án lệ:": "Ap_dung_an_le",
        "Đính chính:": "Dinh_chinh",
        "Thông tin về vụ/việc:": "Thong_tin_ve_vu_viec",
        "Đối tượng khởi kiện:": "Doi_tuong_khoi_kien",
        "Loại án:": "Loai_an",
        "Thông tin về vụ án:": "Thong_tin_ve_vu_an",
        "Tên quyết định:": "Ten_quyet_dinh",
        "Biện pháp xử lý hành chính:": "Bien_phap_xu_ly_hanh_chinh",
        "Loại việc:": "Loai_viec",
        "Thông tin về việc:": "Thong_tin_ve_viec",
        "Đối tượng bị yêu cầu:": "Doi_tuong_bi_yeu_cau",
        "Loại yêu cầu:": "Loai_yeu_cau",
        "Thông tin về yêu cầu:": "Thong_tin_ve_yeu_cau",
    },
    inplace=True,
)

# %%
hinhsu_df = df[(df["Loai_an"] == "Hình sự") & (~df['Ten_ban_an'].isnull())]

# %%
# drop columns
hinhsu_df.drop(
    columns=[
        "Quan_he_phap_luat",
        "Loai_vu_viec",
        "Thong_tin_ve_vu_viec",
        "Doi_tuong_khoi_kien",
        "Ten_quyet_dinh",
        "Bien_phap_xu_ly_hanh_chinh",
        "Loai_viec",
        "Thong_tin_ve_viec",
        "Doi_tuong_bi_yeu_cau",
        "Loai_yeu_cau",
        'Thong_tin_ve_yeu_cau'
    ],
    inplace=True,
)
# Out:
# C:\Users\ngoph\AppData\Local\Temp\ipykernel_11256\4097500478.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hinhsu_df.drop(

# %%
len(hinhsu_df)
# Out:
# 305305

# %%
# check if 'phạm tội' in hinhsu_df['Ten_ban_an'] and 'không phạm tội' not in hinhsu_df['Ten_ban_an']
hinhsu_df[
    hinhsu_df["Ten_ban_an"].str.contains("phạm tội") & ~hinhsu_df["Ten_ban_an"].str.contains("không phạm tội")
]
# Out:
#                       id                                                url  \
# 8            2ta142t1cvn      https://congbobanan.toaan.gov.vn/2ta142t1cvn/
# 9            2ta144t1cvn      https://congbobanan.toaan.gov.vn/2ta144t1cvn/
# 10           2ta147t1cvn      https://congbobanan.toaan.gov.vn/2ta147t1cvn/
# 13           2ta170t1cvn      https://congbobanan.toaan.gov.vn/2ta170t1cvn/
# 22           2ta198t1cvn      https://congbobanan.toaan.gov.vn/2ta198t1cvn/
# ...                  ...                                                ...
# 1571747  2ta1639182t1cvn  https://congbobanan.toaan.gov.vn/2ta1639182t1cvn/
# 1571748  2ta1639196t1cvn  https://congbobanan.toaan.gov.vn/2ta1639196t1cvn/
# 1571751  2ta1639195t1cvn  https://congbobanan.toaan.gov.vn/2ta1639195t1cvn/
# 1571760  2ta1639199t1cvn  https://congbobanan.toaan.gov.vn/2ta1639199t1cvn/
# 1571765  2ta1639206t1cvn  https://congbobanan.toaan.gov.vn/2ta1639206t1cvn/
#
#                                                 Ten_ban_an Cap_xet_xu  \
# 8        Bị cáo Mã Phúc T phạm tội Tàng trữ trái phép c...    Sơ thẩm
# 9        Bị cáo Cứ Thị C - phạm tội  tàng trữ vận chuyể...    Sơ thẩm
# 10       Hoàng Văn T - phạm tội  tàng trữ vận chuyển, m...  Phúc thẩm
# 13       Trang Thanh T - phạm tội  chống người thi hành...  Phúc thẩm
# 22       THÂN TRUNG TÀI VÀ ĐỒNG BỌN  - phạm tội  chống ...    Sơ thẩm
# ...                                                    ...        ...
# 1571747  Trộm cắp tài sản - phạm tội  trộm cắp tài sản ...    Sơ thẩm
# 1571748  Nguyễn Thị D phạm tội Tham ô tài sản - phạm tộ...    Sơ thẩm
# 1571751  Mua bán trái phép chất ma túy - phạm tội  mua ...    Sơ thẩm
# 1571760  Trần Yến T phạm tội cho vay lãi nặng trong gia...    Sơ thẩm
# 1571765  Mua bán trái phép chất ma túy - phạm tội  mua ...    Sơ thẩm
#
#                                   Toa_an_xet_xu Ap_dung_an_le  Dinh_chinh  \
# 8          TAND Thị xã Long Mỹ,  tỉnh Hậu Giang         Không           0
# 9        TAND huyện Mù Cang Chải,  tỉnh Yên Bái         Không           0
# 10                            TAND tỉnh Yên Bái         Không           0
# 13                             TAND TP. Cần Thơ         Không           0
# 22             TAND huyện Đăk Pơ,  tỉnh Gia Lai         Không           0
# ...                                         ...           ...         ...
# 1571747   TAND huyện Bàu Bàng,  tỉnh Bình Dương         Không           0
# 1571748        TAND TP. Việt Trì,  tỉnh Phú Thọ         Không           0
# 1571751           TAND Q. Cầu Giấy,  TP. Hà Nội         Không           0
# 1571760        TAND TP. Việt Trì,  tỉnh Phú Thọ         Không           0
# 1571765           TAND Q. Cầu Giấy,  TP. Hà Nội         Không           0
#
#          Loai_an                                 Thong_tin_ve_vu_an
# 8        Hình sự  Bị cáo Mã Phúc T phạm tội Tàng trữ trái phép c...
# 9        Hình sự  Bị cáo Cứ Thị C đã thực hiện hành vi nhiều lần...
# 10       Hình sự  Xét xử do có kháng nghị của VKSND huyện V về h...
# 13       Hình sự  Không chấp nhận kháng cáo của  bị cáo. \n...
# 22       Hình sự  Thân Trung Tài và đồng bọn phạm tội Chống ngườ...
# ...          ...                                                ...
# 1571747  Hình sự                                       Giàng Mí Chứ
# 1571748  Hình sự               Nguyễn Thị D phạm tội Tham ô tài sản
# 1571751  Hình sự                      Mua bán trái phép chất ma túy
# 1571760  Hình sự  Trần Yến T phạm tội cho vay lãi nặng trong gia...
# 1571765  Hình sự                      Mua bán trái phép chất ma túy
#
# [303336 rows x 9 columns]

# %%
# check ì 'không phạm tội' in hinhsu_df['Ten_ban_an']
temp = hinhsu_df[hinhsu_df['Ten_ban_an'].str.contains('không phạm tội', na=False)]
# save to xlsx
temp.to_excel('./khong_pham_toi.xlsx', index=False)
